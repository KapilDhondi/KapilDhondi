# %% [markdown]
# <a href="https://colab.research.google.com/github/KapilDhondi/KapilDhondi/blob/main/login_email.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
db = open('dataset.txt','w')
import re 

def registration():  
    email = input("Enter Email:\n" )
    pasword = input("Create Password:\n")
    re_enter_pasword = input("Re enter Password:\n")
    db = open("dataset.txt","r") #link dataset.txt
    k = []
    v = []
    for i in db:
        a,b = i.split(",")
        b = b.strip()
        k.append(a)
        v.append(b)
    data = dict(zip(k,v))
    if pasword != re_enter_pasword:#to check password and reenter password match
         print("Password doesnot Match, Try again")
         registration()
    elif len(pasword)<5:
          print("Password too short") 
          registration()
    elif len(pasword)>16:
          print("Password too long")  
          registration()
    elif not re.search(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b',email): #fullmatch is used to match full input as per criteria
          print("Enter a valid Email!!")
          print("\nPlease Register again")
          registration()
    elif not re.search("^(?=.*[a-z])(?=.*[A-Z])(?=.*\d)(?=.*[@$!%*#?&])[A-Za-z\d@$!#%*?&]{5,16}$",pasword):
          print("Enter the valid Password")
          registration() 
    elif email in k:
          print("This Username already exists")
          registration()       
    else:
        db = open("dataset.txt","a") 
        db.write(email+","+pasword+"\n")
        print("Registration Sucessfull")
        Home_page()
        db.close()
    db.close()


def login(): 
    email = input("Enter your email: ")
    pasword = input("Enter you password: ")
    db = open("dataset.txt","r")
    k = []
    v = []
    for i in db:
      a,b = i.split(",")
      b = b.strip()
      c = a,b
      k.append(a)
      v.append(b)
    data = dict(zip(k,v))
    try:
      if data[email]:
        if pasword == data[email]:
          print("Login Successful!")
          Home_page()
        else:
          print("\nIncorrect password or email")
          Home_page()
      else:
        print("\nIncorrect password or email")
        print("Please attempt login again")
        Home_page()
    except:
      print("\nIncorrect password or email")
      Home_page()
    db.close()


def Forget_Password():
  db = open("dataset.txt","r")
  email = input("Enter Email:" )
  k = []
  v = []
  for i in db:
    a,b = i.split(",")
    b = b.strip()
    k.append(a)
    v.append(b)
  data = dict(zip(k,v))
  if email in k:
    print("Your password is: ",data.get(email))
    Home_page()
  else:
     print("Email Doesnot exist")
     print("Please Register!!")
     registration()
  db.close()


def Home_page():
    print("1.Registration")
    print("2.Login")
    print("3.Forget Password")
    print("4.Logout")
    choice = int(input("Enter your choice: "))
    print("*********************************************")
    if choice == 1:
        registration()
    elif choice == 2:
        login()
    elif choice == 3:
        Forget_Password()
    elif choice == 4:
        print("Thank You Visit Again")
        quit()
    else:
        print("Enter the correct choice!")
        Home_page()
Home_page()
